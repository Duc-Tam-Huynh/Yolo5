# %% [markdown]
# # <a href="https://colab.research.google.com/github/Duc-Tam-Huynh/Yolo5/blob/main/Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Duc-Tam-Huynh/Yolo5
# Out:
# Cloning into 'Yolo5'...
# remote: Enumerating objects: 469, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 469 (delta 7), reused 0 (delta 0), pack-reused 436
# Receiving objects: 100% (469/469), 54.71 MiB | 30.95 MiB/s, done.
# Resolving deltas: 100% (50/50), done.

# %%
# !pip install -r /content/Yolo5/yolov5/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 14.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.9 MB/s eta 0:00:00
# ...

# %%
# !python /content/Yolo5/yolov5/train.py --img 416 --batch 16   --epochs 100 --data coco128.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=Yolo5/yolov5/data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Yolo5/yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2023-4-12 Python-3.9.16 torch-2.0.0+cu118 CPU
#
# ...

# %%
# kiem tra '/content/yolov5/runs/train/exp4/weights/best.pt' trong file detect.py
# !python /content/Yolo5/yolov5/detect.py --source /content/Yolo5/panda1.jpg

# %%
# !python /content/Yolo5/yolov5/detect.py --source /content/Yolo5/custom_dataset/images_and_labels/images/test
# Out:
# detect: weights=/content/Yolo5/yolov5/runs/train/exp2/weights/best.pt, source=/content/Yolo5/custom_dataset/images_and_labels/images/test, data=Yolo5/yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=Yolo5/yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2023-4-12 Python-3.9.16 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/3 /content/Yolo5/custom_dataset/images_and_labels/images/test/256dff3fb9802ce3.jpg: 480x640 1 panda, 291.2ms
# image 2/3 /content/Yolo5/custom_dataset/images_and_labels/images/test/26085cba0c11b8ee.jpg: 448x640 2 pandas, 263.6ms
# ...

# %%
# !python /content/Yolo5/yolov5/detect.py --source 'https://www.youtube.com/watch?v=sGF6bOi1NfA'
# Out:
# detect: weights=/content/Yolo5/yolov5/runs/train/exp2/weights/best.pt, source=https://www.youtube.com/watch?v=sGF6bOi1NfA, data=Yolo5/yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=Yolo5/yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2023-4-12 Python-3.9.16 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# requirements: YOLOv5 requirements "pafy" "youtube_dl==2020.12.2" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
